# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Cargar el dataset
report=pd.read_csv('../Data/Student_Satisfaction_Survey.csv',encoding ='latin-1')

# %% [markdown]
# # Variables.
# - ``SN:`` Número de serie de la pregunta de la encuesta.
# - ``Total Feedback Given:`` Número de estudiantes seleccionados para dar su retroalimentación por curso.
# - ``Total Configured:`` Total de estudiantes en el curso.
# - ``Questions:`` Lista de 20 preguntas de la encuesta.
# - ``Weightage 1:`` Puntuación más baja en la escala.
# - ``Weightage 2:`` Puntuación por debajo del promedio pero mejor que la más baja.
# - ``Weightage 3:`` Puntuación promedio.
# - ``Weightage 4:`` Puntuación por encima del promedio.
# - ``Weightage 5:`` Mejor puntuación.
# - ``Average/Percentage:`` Promedio ponderado mostrado tanto en términos absolutos como en porcentaje.
# - ``Course Name:`` Año actual de la Graduación/Postgrado.
# - ``Basic Course:`` Rama de Graduación/Postgrado.

# %%
# Vista previa de las primeras filas del dataset
report.head()
# Out:
#    SN  Total Feedback Given  Total Configured  \
# 0   1                     1                12
# 1   2                     1                12
# 2   3                     1                12
# 3   4                     1                12
# 4   5                     1                12
#
#                                            Questions  Weightage 1  \
# 0  How much of the syllabus was covered in the cl...            0
# 1  How well did the teachers prepare for the clas...            0
# 2    How well were the teachers able to communicate?            0
# 3  The teachers approach to teaching can best be...            0
# 4  Fairness of the internal evaluation process by...            0
#
#    Weightage 2  Weightage 3  Weightage 4  Weightage 5 Average/ Percentage  \
# 0            0            1            0            0        3.00 / 60.00
# 1            0            0            0            1       5.00 / 100.00
# ...

# %%
# Información adicional del dataset
report.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 580 entries, 0 to 579
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   SN                    580 non-null    int64
#  1   Total Feedback Given  580 non-null    int64
#  2   Total Configured      580 non-null    int64
#  3   Questions             580 non-null    object
#  4   Weightage 1           580 non-null    int64
#  5   Weightage 2           580 non-null    int64
#  6   Weightage 3           580 non-null    int64
#  7   Weightage 4           580 non-null    int64
#  8   Weightage 5           580 non-null    int64
#  9   Average/ Percentage   580 non-null    object
#  10  Course Name           580 non-null    object
#  11  Basic Course          580 non-null    object
# dtypes: int64(8), object(4)
# memory usage: 54.5+ KB

# %%
# Se filtra la variable Questions
report['Questions'].value_counts()
# Out:
# Questions
# How much of the syllabus was covered in the class?                                                                                                                                  29
# How well did the teachers prepare for the classes?                                                                                                                                  29
# What percentage of teachers use ICT tools such as LCD projectors, Multimedia, etc. while teaching?                                                                                  29
# Efforts are made by the institute/ teachers to inculcate soft skills, life skills and employability skills to make you ready for the world of work.                                 29
# Teachers encourage you to participate in extracurricular activities.                                                                                                                29
# ...

# %% [markdown]
# ## Preguntas traducidas.
#
# ¿Cuánto del programa de estudios se cubrió en la clase? 29
#
# ¿Qué tan bien se prepararon los profesores para las clases? 29
#
# ¿Qué porcentaje de profesores utiliza herramientas TIC como proyectores LCD, multimedia, etc., al enseñar? 29
#
# Se realizan esfuerzos por parte del instituto/profesores para inculcar habilidades blandas, habilidades para la vida y habilidades de empleabilidad para prepararte para el mundo laboral. 29
#
# Los profesores te animan a participar en actividades extracurriculares. 29
#
# El instituto/profesores utilizan métodos centrados en el estudiante, como el aprendizaje experiencial, el aprendizaje participativo y las metodologías de resolución de problemas para mejorar las experiencias de aprendizaje. 29
#
# La institución hace esfuerzos para involucrar a los estudiantes en el monitoreo, revisión y mejora continua de la calidad del proceso de enseñanza-aprendizaje. 29
#
# Los profesores son capaces de identificar tus debilidades y ayudarte a superarlas. 29
#
# Los profesores identifican tus fortalezas y te animan a enfrentar los desafíos adecuados. 29
#
# Los profesores ilustran los conceptos a través de ejemplos y aplicaciones. 29
#
# Tu mentor hace un seguimiento necesario de una tarea asignada a ti. 29
#
# Los profesores te informan sobre tus competencias esperadas, resultados del curso y resultados del programa. 29
#
# La institución proporciona múltiples oportunidades para aprender y crecer. 29
#
# El proceso de enseñanza y mentoría en tu institución te facilita el crecimiento cognitivo, social y emocional. 29
#
# El instituto muestra un interés activo en promover prácticas, intercambios estudiantiles y oportunidades de visitas de campo para los estudiantes. 29
#
# ¿Se discutió tu desempeño en las tareas contigo? 29
#
# Justicia del proceso de evaluación interna por parte de los profesores. 29
#
# La mejor descripción del enfoque de enseñanza del profesor es 29
#
# ¿Qué tan bien fueron capaces de comunicarse los profesores? 29
#
# La calidad general del proceso de enseñanza-aprendizaje en tu instituto es muy buena.

# %%
#Total de encuestas realizadas.
report['SN'].value_counts()
# Out:
# SN
# 1     29
# 2     29
# 19    29
# 18    29
# 17    29
# 16    29
# 15    29
# 14    29
# 13    29
# 12    29
# 11    29
# 10    29
# 9     29
# 8     29
# 7     29
# 6     29
# 5     29
# 4     29
# 3     29
# 20    29
# Name: count, dtype: int64

# %%
#Filtramos la variable (Total Feedback Given)
report['Total Feedback Given'].value_counts()
# Out:
# Total Feedback Given
# 7     80
# 1     60
# 3     60
# 4     40
# 2     40
# 14    40
# 17    40
# 26    20
# 12    20
# 5     20
# 20    20
# 74    20
# 6     20
# 46    20
# 37    20
# 27    20
# 39    20
# 9     20
# Name: count, dtype: int64

# %%
#Filtramos la variable (Total Configured)
report['Total Configured'].value_counts()
# Out:
# Total Configured
# 20     80
# 24     60
# 12     20
# 22     20
# 105    20
# 331    20
# 118    20
# 48     20
# 159    20
# 123    20
# 559    20
# 137    20
# 18     20
# 14     20
# 144    20
# 44     20
# 21     20
# 42     20
# 15     20
# 175    20
# 122    20
# 33     20
# 119    20
# 170    20
# Name: count, dtype: int64

# %%
#Filtramos la variable (Weightage 1)
report['Weightage 1'].value_counts()
# Out:
# Weightage 1
# 0     407
# 1     112
# 2      36
# 3      12
# 4       6
# 6       2
# 19      1
# 10      1
# 9       1
# 5       1
# 7       1
# Name: count, dtype: int64

# %%
#Filtramos la variable (Weightage 2)
report['Weightage 2'].value_counts()
# Out:
# Weightage 2
# 0    291
# 1    123
# 2     64
# 3     41
# 4     25
# 5     15
# 7     10
# 6      9
# 8      2
# Name: count, dtype: int64

# %%
#Filtramos la variable (Weightage 3)
report['Weightage 3'].value_counts()
# Out:
# Weightage 3
# 0     164
# 1     131
# 2      79
# 3      61
# 4      41
# 5      26
# 6      17
# 7      14
# 8      13
# 9       9
# 10      6
# 11      6
# 12      4
# 13      4
# 22      1
# 26      1
# 17      1
# 14      1
# 16      1
# Name: count, dtype: int64

# %%
#Filtramos la variable (Weightage 4)
report['Weightage 4'].value_counts()
# Out:
# Weightage 4
# 1     108
# 0     103
# 2      72
# 3      66
# 4      37
# 5      31
# 6      22
# 7      21
# 8      18
# 9      17
# 10     14
# 11      8
# 14      7
# 13      7
# 27      5
# 19      4
# 16      4
# 12      4
# 15      4
# 18      3
# 24      3
# 21      3
# 34      2
# 30      2
# 32      2
# 35      2
# 17      2
# 43      1
# 40      1
# 46      1
# 44      1
# 28      1
# 25      1
# 52      1
# 20      1
# 36      1
# Name: count, dtype: int64

# %%
#Filtramos la variable (Weightage 5)
report['Weightage 5'].value_counts()
# Out:
# Weightage 5
# 0     122
# 1     113
# 2      51
# 3      50
# 4      42
# 6      30
# 5      29
# 8      16
# 13     16
# 10     15
# 7      12
# 14     11
# 11     10
# 15      9
# 12      8
# 16      7
# 9       7
# 17      5
# 19      4
# 21      3
# 18      2
# 25      2
# 24      2
# 33      2
# 35      2
# 23      1
# 32      1
# 27      1
# 30      1
# 34      1
# 38      1
# 20      1
# 36      1
# 31      1
# 22      1
# Name: count, dtype: int64

# %%
#Filtramos la variable (Average/ Percentage)
report['Average/ Percentage'].value_counts()
# Out:
# Average/ Percentage
# 4.00 / 80.00     59
# 3.00 / 60.00     38
# 5.00 / 100.00    34
# 4.50 / 90.00     22
# 3.50 / 70.00     21
#                  ..
# 4.15 / 82.97      1
# 4.18 / 83.53      1
# 4.12 / 82.35      1
# 4.86 / 97.14      1
# 4.89 / 97.78      1
# Name: count, Length: 152, dtype: int64

# %%
#Filtramos la variable (Course Name )
report['Course Name '].value_counts()
# Out:
# Course Name
# FY B.VOC FOOD TECHNOLOGY            20
# MSC DATA SCIENCE - 3                20
# TYBMS                               20
# TYBCOM                              20
# TYBA                                20
# SY COMPUTER SCIENCE                 20
# SYBSC                               20
# SYBMS                               20
# SYBCOM                              20
# S.Y.B.A.F                           20
# MSC PHYSICS - 3                     20
# MSC ORGANIC CHEMISTRY - 3           20
# MSC MICROBIOLOGY - 3                20
# MSC INFORMATION TECHNOLOGY - 3      20
# M.SC PART - 2 COMPUTER SCIENCE      20
# FYBA                                20
# MSC ANALYTICAL CHEMISTRY SEM III    20
# MSC MICROBIOLOGY - 1                20
# MSC INFORMATION TECHNOLOGY - 1      20
# MSC DATA SCIENCE - 1                20
# MSC ANALYTICAL CHEMISTRY SEM I      20
# M.SC PART - 1 COMPUTER SCIENCE      20
# MA PSYCHOLOGY - 3                   20
# MA PSYCHOLOGY - 1                   20
# ...

# %%
#Agrupamos la variable ('Basic Course')  y  ['Course Name ']
cursos=report.groupby('Basic Course')['Course Name '].count()

# %%
cursos
# Out:
# Basic Course
# B.SC. COMPUTER SCIENCE                           20
# B.VOC FOOD TECHNOLOGY                            20
# BACHELOR OF ARTS                                 40
# BACHELOR OF COMMERCE                             40
# BACHELOR OF COMMERCE (ACCOUNTING AND FINANCE)    40
# BACHELOR OF COMMERCE (BANKING AND INSURANCE)     20
# BACHELOR OF MANAGEMENT STUDIES                   60
# BACHELOR OF SCIENCE                              60
# MA PSYCHOLOGY                                    40
# MSC ANALYTICAL CHEMISTRY                         40
# MSC COMPUTER SCIENCE                             40
# MSC DATA SCIENCE                                 40
# MSC INFORMATION TECHNOLOGY                       40
# MSC MICROBIOLOGY                                 40
# MSC ORGANIC CHEMISTRY                            20
# MSC PHYSICS                                      20
# Name: Course Name , dtype: int64

# %% [markdown]
# # Graficas de resultado de cada pregunta.|

# %%
pregunta1=report[report['Questions']== 'How much of the syllabus was covered in the class?'][['Weightage 1','Weightage 2','Weightage 3','Weightage 4','Weightage 5']].sum()

# %%
pregunta1
# Out:
# Weightage 1      7
# Weightage 2     32
# Weightage 3     86
# Weightage 4    120
# Weightage 5    170
# dtype: int64

# %%
pregunta1=report[report['Questions']== 'How much of the syllabus was covered in the class?'][['Weightage 1','Weightage 2','Weightage 3','Weightage 4','Weightage 5']].sum()
dic = {'Weightage 1': 'Puntuación más baja en la escala.', 'Weightage 2': 'Puntuación por debajo del promedio pero mejor que la más baja.', 'Weightage 3':'Puntuación promedio.',
      'Weightage 4':'Puntuación por encima del promedio.' , 'Weightage 5': 'Mejor puntuación.'}
lis = ['Puntuación más baja en la escala.','Puntuación por debajo del promedio pero mejor que la más baja.','Puntuación promedio.','Puntuación por encima del promedio.' ,'Mejor puntuación.']
plt.figure(figsize=(10,6))  #tamaño de gráfico
plt.bar(lis,pregunta1.values,color='red')
plt.title('¿Cuánto del programa de estudios se cubrió en la clase?')
plt.xlabel('Opciones')#poner etiqueta a eje x
plt.ylabel('Puntuación')#poner etiqueta a eje y
plt.xticks(rotation=90)

## Mostrar las etiquetas en barras
for i, value in enumerate(pregunta1.values):
    plt.text(i, value, str(value), ha='center', va='bottom')

plt.show()#mostrar Gráfico

# %%
pregunta2=report[report['Questions']== 'How much of the syllabus was covered in the class?'][['Weightage 1','Weightage 2','Weightage 3','Weightage 4','Weightage 5']].sum()

# %%
pregunta2
# Out:
# Weightage 1      7
# Weightage 2     32
# Weightage 3     86
# Weightage 4    120
# Weightage 5    170
# dtype: int64

# %%
pregunta2=report[report['Questions']== 'How much of the syllabus was covered in the class?'][['Weightage 1','Weightage 2','Weightage 3','Weightage 4','Weightage 5']].sum()
dic = {'Weightage 1': 'Puntuación más baja en la escala.', 'Weightage 2': 'Puntuación por debajo del promedio pero mejor que la más baja.', 'Weightage 3':'Puntuación promedio.',
      'Weightage 4':'Puntuación por encima del promedio.' , 'Weightage 5': 'Mejor puntuación.'}
lis = ['Puntuación más baja en la escala.','Puntuación por debajo del promedio pero mejor que la más baja.','Puntuación promedio.','Puntuación por encima del promedio.' ,'Mejor puntuación.']
plt.figure(figsize=(10,6))  #tamaño de gráfico
plt.bar(lis,pregunta2.values,color='red')
plt.title('¿Qué tan bien se prepararon los profesores para las clases?')
plt.xlabel('Opciones')#poner etiqueta a eje x
plt.ylabel('Puntuación')#poner etiqueta a eje y
plt.xticks(rotation=90)

## Mostrar las etiquetas en barras
for i, value in enumerate(pregunta2.values):
    plt.text(i, value, str(value), ha='center', va='bottom')

plt.show()#mostrar Gráfico

# %%
pregunta3=report[report['Questions']== 'What percentage of teachers use ICT tools such as LCD projectors, Multimedia, etc. while teaching?'][['Weightage 1','Weightage 2','Weightage 3','Weightage 4','Weightage 5']].sum()

# %%
pregunta3
# Out:
# Weightage 1     62
# Weightage 2     37
# Weightage 3    107
# Weightage 4    125
# Weightage 5     84
# dtype: int64

# %%
pregunta3=report[report['Questions']== 'What percentage of teachers use ICT tools such as LCD projectors, Multimedia, etc. while teaching?'][['Weightage 1','Weightage 2','Weightage 3','Weightage 4','Weightage 5']].sum()
dic = {'Weightage 1': 'Puntuación más baja en la escala.', 'Weightage 2': 'Puntuación por debajo del promedio pero mejor que la más baja.', 'Weightage 3':'Puntuación promedio.',
      'Weightage 4':'Puntuación por encima del promedio.' , 'Weightage 5': 'Mejor puntuación.'}
lis = ['Puntuación más baja en la escala.','Puntuación por debajo del promedio pero mejor que la más baja.','Puntuación promedio.','Puntuación por encima del promedio.' ,'Mejor puntuación.']
plt.figure(figsize=(10,6))  #tamaño de gráfico
plt.bar(lis,pregunta3.values,color='red')
plt.title('¿Qué porcentaje de profesores utiliza herramientas TIC como proyectores LCD, multimedia, etc., al enseñar?')
plt.xlabel('Opciones')#poner etiqueta a eje x
plt.ylabel('Puntuación')#poner etiqueta a eje y
plt.xticks(rotation=90)

## Mostrar las etiquetas en barras
for i, value in enumerate(pregunta3.values):
    plt.text(i, value, str(value), ha='center', va='bottom')

plt.show()#mostrar Gráfico

# %%
pregunta4=report[report['Questions']== 'Efforts are made by the institute/ teachers to inculcate soft skills, life skills and employability skills to make you ready for the world of work.'][['Weightage 1','Weightage 2','Weightage 3','Weightage 4','Weightage 5']].sum()

# %%
pregunta4
# Out:
# Weightage 1     12
# Weightage 2     39
# Weightage 3     65
# Weightage 4    158
# Weightage 5    141
# dtype: int64

# %%
pregunta4=report[report['Questions']== 'Efforts are made by the institute/ teachers to inculcate soft skills, life skills and employability skills to make you ready for the world of work.'][['Weightage 1','Weightage 2','Weightage 3','Weightage 4','Weightage 5']].sum()
dic = {'Weightage 1': 'Puntuación más baja en la escala.', 'Weightage 2': 'Puntuación por debajo del promedio pero mejor que la más baja.', 'Weightage 3':'Puntuación promedio.',
      'Weightage 4':'Puntuación por encima del promedio.' , 'Weightage 5': 'Mejor puntuación.'}
lis = ['Puntuación más baja en la escala.','Puntuación por debajo del promedio pero mejor que la más baja.','Puntuación promedio.','Puntuación por encima del promedio.' ,'Mejor puntuación.']
plt.figure(figsize=(10,6))  #tamaño de gráfico
plt.bar(lis,pregunta4.values,color='red')
plt.title('Se realizan esfuerzos por parte del instituto/profesores para inculcar habilidades blandas, habilidades para la vida y habilidades de empleabilidad para prepararte para el mundo laboral')
plt.xlabel('Opciones')#poner etiqueta a eje x
plt.ylabel('Puntuación')#poner etiqueta a eje y
plt.xticks(rotation=90)

## Mostrar las etiquetas en barras
for i, value in enumerate(pregunta4.values):
    plt.text(i, value, str(value), ha='center', va='bottom')

plt.show()#mostrar Gráfico

# %%
pregunta5=report[report['Questions']== 'Teachers encourage you to participate in extracurricular activities.'][['Weightage 1','Weightage 2','Weightage 3','Weightage 4','Weightage 5']].sum()

# %%
pregunta5
# Out:
# Weightage 1     11
# Weightage 2     24
# Weightage 3     77
# Weightage 4    162
# Weightage 5    141
# dtype: int64

# %%
pregunta5=report[report['Questions']== 'Teachers encourage you to participate in extracurricular activities.'][['Weightage 1','Weightage 2','Weightage 3','Weightage 4','Weightage 5']].sum()
dic = {'Weightage 1': 'Puntuación más baja en la escala.', 'Weightage 2': 'Puntuación por debajo del promedio pero mejor que la más baja.', 'Weightage 3':'Puntuación promedio.',
      'Weightage 4':'Puntuación por encima del promedio.' , 'Weightage 5': 'Mejor puntuación.'}
lis = ['Puntuación más baja en la escala.','Puntuación por debajo del promedio pero mejor que la más baja.','Puntuación promedio.','Puntuación por encima del promedio.' ,'Mejor puntuación.']
plt.figure(figsize=(10,6))  #tamaño de gráfico
plt.bar(lis,pregunta5.values,color='red')
plt.title('Los profesores te animan a participar en actividades extracurriculares.')
plt.xlabel('Opciones')#poner etiqueta a eje x
plt.ylabel('Puntuación')#poner etiqueta a eje y
plt.xticks(rotation=90)

## Mostrar las etiquetas en barras
for i, value in enumerate(pregunta5.values):
    plt.text(i, value, str(value), ha='center', va='bottom')

plt.show()#mostrar Gráfico

# %%
pregunta6=report[report['Questions']== 'The institute/ teachers use student-centric methods, such as experiential learning, participative learning and problem-solving methodologies for enhancing learning experiences. '][['Weightage 1','Weightage 2','Weightage 3','Weightage 4','Weightage 5']].sum()

# %%
pregunta6
# Out:
# Weightage 1    0
# Weightage 2    0
# Weightage 3    0
# Weightage 4    0
# Weightage 5    0
# dtype: int64

# %%
pregunta6=report[report['Questions']== 'The institute/ teachers use student-centric methods, such as experiential learning, participative learning and problem-solving methodologies for enhancing learning experiences.'][['Weightage 1','Weightage 2','Weightage 3','Weightage 4','Weightage 5']].sum()
dic = {'Weightage 1': 'Puntuación más baja en la escala.', 'Weightage 2': 'Puntuación por debajo del promedio pero mejor que la más baja.', 'Weightage 3':'Puntuación promedio.',
      'Weightage 4':'Puntuación por encima del promedio.' , 'Weightage 5': 'Mejor puntuación.'}
lis = ['Puntuación más baja en la escala.','Puntuación por debajo del promedio pero mejor que la más baja.','Puntuación promedio.','Puntuación por encima del promedio.' ,'Mejor puntuación.']
plt.figure(figsize=(10,6))  #tamaño de gráfico
plt.bar(lis,pregunta6.values,color='red')
plt.title('El instituto/profesores utilizan métodos centrados en el estudiante, como el aprendizaje experiencial, el aprendizaje participativo y las metodologías de resolución de problemas para mejorar las experiencias de aprendizaje.')
plt.xlabel('Opciones')#poner etiqueta a eje x
plt.ylabel('Puntuación')#poner etiqueta a eje y
plt.xticks(rotation=90)

## Mostrar las etiquetas en barras
for i, value in enumerate(pregunta6.values):
    plt.text(i, value, str(value), ha='center', va='bottom')

plt.show()#mostrar Gráfico

# %%
pregunta7=report[report['Questions']== 'The institution makes effort to engage students in the monitoring, review and continuous quality improvement of the teaching-learning process.'][['Weightage 1','Weightage 2','Weightage 3','Weightage 4','Weightage 5']].sum()

# %%
pregunta7
# Out:
# Weightage 1     10
# Weightage 2     32
# Weightage 3     75
# Weightage 4    186
# Weightage 5    112
# dtype: int64

# %%
pregunta7=report[report['Questions']== 'The institution makes effort to engage students in the monitoring, review and continuous quality improvement of the teaching-learning process.'][['Weightage 1','Weightage 2','Weightage 3','Weightage 4','Weightage 5']].sum()
dic = {'Weightage 1': 'Puntuación más baja en la escala.', 'Weightage 2': 'Puntuación por debajo del promedio pero mejor que la más baja.', 'Weightage 3':'Puntuación promedio.',
      'Weightage 4':'Puntuación por encima del promedio.' , 'Weightage 5': 'Mejor puntuación.'}
lis = ['Puntuación más baja en la escala.','Puntuación por debajo del promedio pero mejor que la más baja.','Puntuación promedio.','Puntuación por encima del promedio.' ,'Mejor puntuación.']
plt.figure(figsize=(10,6))  #tamaño de gráfico
plt.bar(lis,pregunta7.values,color='red')
plt.title('La institución hace esfuerzos para involucrar a los estudiantes en el monitoreo, revisión y mejora continua de la calidad del proceso de enseñanza-aprendizaje.')
plt.xlabel('Opciones')#poner etiqueta a eje x
plt.ylabel('Puntuación')#poner etiqueta a eje y
plt.xticks(rotation=90)

## Mostrar las etiquetas en barras
for i, value in enumerate(pregunta7.values):
    plt.text(i, value, str(value), ha='center', va='bottom')

plt.show()#mostrar Gráfico

# %%
pregunta8=report[report['Questions']== 'Teachers are able to identify your weaknesses and help you to overcome them.'][['Weightage 1','Weightage 2','Weightage 3','Weightage 4','Weightage 5']].sum()

# %%
pregunta8
# Out:
# Weightage 1     20
# Weightage 2     51
# Weightage 3     69
# Weightage 4    132
# Weightage 5    143
# dtype: int64

# %%
pregunta8=report[report['Questions']== 'Teachers are able to identify your weaknesses and help you to overcome them.'][['Weightage 1','Weightage 2','Weightage 3','Weightage 4','Weightage 5']].sum()
dic = {'Weightage 1': 'Puntuación más baja en la escala.', 'Weightage 2': 'Puntuación por debajo del promedio pero mejor que la más baja.', 'Weightage 3':'Puntuación promedio.',
      'Weightage 4':'Puntuación por encima del promedio.' , 'Weightage 5': 'Mejor puntuación.'}
lis = ['Puntuación más baja en la escala.','Puntuación por debajo del promedio pero mejor que la más baja.','Puntuación promedio.','Puntuación por encima del promedio.' ,'Mejor puntuación.']
plt.figure(figsize=(10,6))  #tamaño de gráfico
plt.bar(lis,pregunta8.values,color='red')
plt.title('Los profesores son capaces de identificar tus debilidades y ayudarte a superarlas.')
plt.xlabel('Opciones')#poner etiqueta a eje x
plt.ylabel('Puntuación')#poner etiqueta a eje y
plt.xticks(rotation=90)

## Mostrar las etiquetas en barras
for i, value in enumerate(pregunta8.values):
    plt.text(i, value, str(value), ha='center', va='bottom')

plt.show()#mostrar Gráfico

# %%
pregunta9=report[report['Questions']== 'The teachers identify your strengths and encourage you to provide the proper level of challenges.'][['Weightage 1','Weightage 2','Weightage 3','Weightage 4','Weightage 5']].sum()

# %%
pregunta9
# Out:
# Weightage 1     24
# Weightage 2     39
# Weightage 3     58
# Weightage 4    129
# Weightage 5    165
# dtype: int64

# %%
pregunta9=report[report['Questions']== 'The teachers identify your strengths and encourage you to provide the proper level of challenges'][['Weightage 1','Weightage 2','Weightage 3','Weightage 4','Weightage 5']].sum()
dic = {'Weightage 1': 'Puntuación más baja en la escala.', 'Weightage 2': 'Puntuación por debajo del promedio pero mejor que la más baja.', 'Weightage 3':'Puntuación promedio.',
      'Weightage 4':'Puntuación por encima del promedio.' , 'Weightage 5': 'Mejor puntuación.'}
lis = ['Puntuación más baja en la escala.','Puntuación por debajo del promedio pero mejor que la más baja.','Puntuación promedio.','Puntuación por encima del promedio.' ,'Mejor puntuación.']
plt.figure(figsize=(10,6))  #tamaño de gráfico
plt.bar(lis,pregunta9.values,color='red')
plt.title('Los profesores identifican tus fortalezas y te animan a enfrentar los desafíos adecuados.')
plt.xlabel('Opciones')#poner etiqueta a eje x
plt.ylabel('Puntuación')#poner etiqueta a eje y
plt.xticks(rotation=90)

## Mostrar las etiquetas en barras
for i, value in enumerate(pregunta9.values):
    plt.text(i, value, str(value), ha='center', va='bottom')

plt.show()#mostrar Gráfico

# %%
pregunta10=report[report['Questions']== 'The teachers illustrate the concepts through examples and applications.'][['Weightage 1','Weightage 2','Weightage 3','Weightage 4','Weightage 5']].sum()

# %%
pregunta10
# Out:
# Weightage 1     16
# Weightage 2     41
# Weightage 3     53
# Weightage 4    122
# Weightage 5    183
# dtype: int64

# %%
pregunta10=report[report['Questions']== 'The teachers illustrate the concepts through examples and applications.'][['Weightage 1','Weightage 2','Weightage 3','Weightage 4','Weightage 5']].sum()
dic = {'Weightage 1': 'Puntuación más baja en la escala.', 'Weightage 2': 'Puntuación por debajo del promedio pero mejor que la más baja.', 'Weightage 3':'Puntuación promedio.',
      'Weightage 4':'Puntuación por encima del promedio.' , 'Weightage 5': 'Mejor puntuación.'}
lis = ['Puntuación más baja en la escala.','Puntuación por debajo del promedio pero mejor que la más baja.','Puntuación promedio.','Puntuación por encima del promedio.' ,'Mejor puntuación.']
plt.figure(figsize=(10,6))  #tamaño de gráfico
plt.bar(lis,pregunta10.values,color='red')
plt.title('Los profesores ilustran los conceptos a través de ejemplos y aplicaciones.')
plt.xlabel('Opciones')#poner etiqueta a eje x
plt.ylabel('Puntuación')#poner etiqueta a eje y
plt.xticks(rotation=90)

## Mostrar las etiquetas en barras
for i, value in enumerate(pregunta10.values):
    plt.text(i, value, str(value), ha='center', va='bottom')

plt.show()#mostrar Gráfico

# %%
pregunta11=report[report['Questions']== 'Your mentor does a necessary follow-up with an assigned task to you.'][['Weightage 1','Weightage 2','Weightage 3','Weightage 4','Weightage 5']].sum()

# %%
pregunta11
# Out:
# Weightage 1     22
# Weightage 2     39
# Weightage 3     69
# Weightage 4    130
# Weightage 5    155
# dtype: int64

# %%
pregunta11=report[report['Questions']== 'Your mentor does a necessary follow-up with an assigned task to you.'][['Weightage 1','Weightage 2','Weightage 3','Weightage 4','Weightage 5']].sum()
dic = {'Weightage 1': 'Puntuación más baja en la escala.', 'Weightage 2': 'Puntuación por debajo del promedio pero mejor que la más baja.', 'Weightage 3':'Puntuación promedio.',
      'Weightage 4':'Puntuación por encima del promedio.' , 'Weightage 5': 'Mejor puntuación.'}
lis = ['Puntuación más baja en la escala.','Puntuación por debajo del promedio pero mejor que la más baja.','Puntuación promedio.','Puntuación por encima del promedio.' ,'Mejor puntuación.']
plt.figure(figsize=(10,6))  #tamaño de gráfico
plt.bar(lis,pregunta11.values,color='red')
plt.title('Tu mentor hace un seguimiento necesario de una tarea asignada a ti.')
plt.xlabel('Opciones')#poner etiqueta a eje x
plt.ylabel('Puntuación')#poner etiqueta a eje y
plt.xticks(rotation=90)

## Mostrar las etiquetas en barras
for i, value in enumerate(pregunta11.values):
    plt.text(i, value, str(value), ha='center', va='bottom')

plt.show()#mostrar Gráfico

# %%
pregunta12=report[report['Questions']== 'Teachers inform you about your expected competencies, course outcomes and program\noutcomes.'][['Weightage 1','Weightage 2','Weightage 3','Weightage 4','Weightage 5']].sum()

# %%
pregunta12
# Out:
# Weightage 1     13
# Weightage 2     35
# Weightage 3     51
# Weightage 4    147
# Weightage 5    169
# dtype: int64

# %%
pregunta12=report[report['Questions']== 'Teachers inform you about your expected competencies, course outcomes and program\noutcomes.'][['Weightage 1','Weightage 2','Weightage 3','Weightage 4','Weightage 5']].sum()
dic = {'Weightage 1': 'Puntuación más baja en la escala.', 'Weightage 2': 'Puntuación por debajo del promedio pero mejor que la más baja.', 'Weightage 3':'Puntuación promedio.',
      'Weightage 4':'Puntuación por encima del promedio.' , 'Weightage 5': 'Mejor puntuación.'}
lis = ['Puntuación más baja en la escala.','Puntuación por debajo del promedio pero mejor que la más baja.','Puntuación promedio.','Puntuación por encima del promedio.' ,'Mejor puntuación.']
plt.figure(figsize=(10,6))  #tamaño de gráfico
plt.bar(lis,pregunta12.values,color='red')
plt.title('Los profesores te informan sobre tus competencias esperadas, resultados del curso y resultados del programa.')
plt.xlabel('Opciones')#poner etiqueta a eje x
plt.ylabel('Puntuación')#poner etiqueta a eje y
plt.xticks(rotation=90)

## Mostrar las etiquetas en barras
for i, value in enumerate(pregunta12.values):
    plt.text(i, value, str(value), ha='center', va='bottom')

plt.show()#mostrar Gráfico

# %%
pregunta13=report[report['Questions']== 'The institution provides multiple opportunities to learn and grow.'][['Weightage 1','Weightage 2','Weightage 3','Weightage 4','Weightage 5']].sum()

# %%
pregunta13
# Out:
# Weightage 1     10
# Weightage 2     24
# Weightage 3     91
# Weightage 4    176
# Weightage 5    114
# dtype: int64

# %%
pregunta13=report[report['Questions']== 'The institution provides multiple opportunities to learn and grow.'][['Weightage 1','Weightage 2','Weightage 3','Weightage 4','Weightage 5']].sum()
dic = {'Weightage 1': 'Puntuación más baja en la escala.', 'Weightage 2': 'Puntuación por debajo del promedio pero mejor que la más baja.', 'Weightage 3':'Puntuación promedio.',
      'Weightage 4':'Puntuación por encima del promedio.' , 'Weightage 5': 'Mejor puntuación.'}
lis = ['Puntuación más baja en la escala.','Puntuación por debajo del promedio pero mejor que la más baja.','Puntuación promedio.','Puntuación por encima del promedio.' ,'Mejor puntuación.']
plt.figure(figsize=(10,6))  #tamaño de gráfico
plt.bar(lis,pregunta13.values,color='red')
plt.title('La institución proporciona múltiples oportunidades para aprender y crecer.')
plt.xlabel('Opciones')#poner etiqueta a eje x
plt.ylabel('Puntuación')#poner etiqueta a eje y
plt.xticks(rotation=90)

## Mostrar las etiquetas en barras
for i, value in enumerate(pregunta13.values):
    plt.text(i, value, str(value), ha='center', va='bottom')

plt.show()#mostrar Gráfico

# %%
pregunta14=report[report['Questions']== 'The teaching and mentoring process in your institution facilitates you in cognitive, social and\nemotional growth.'][['Weightage 1','Weightage 2','Weightage 3','Weightage 4','Weightage 5']].sum()

# %%
pregunta14
# Out:
# Weightage 1     18
# Weightage 2     41
# Weightage 3     70
# Weightage 4    174
# Weightage 5    112
# dtype: int64

# %%
pregunta14=report[report['Questions']== 'The teaching and mentoring process in your institution facilitates you in cognitive, social and\nemotional growth.'][['Weightage 1','Weightage 2','Weightage 3','Weightage 4','Weightage 5']].sum()
dic = {'Weightage 1': 'Puntuación más baja en la escala.', 'Weightage 2': 'Puntuación por debajo del promedio pero mejor que la más baja.', 'Weightage 3':'Puntuación promedio.',
      'Weightage 4':'Puntuación por encima del promedio.' , 'Weightage 5': 'Mejor puntuación.'}
lis = ['Puntuación más baja en la escala.','Puntuación por debajo del promedio pero mejor que la más baja.','Puntuación promedio.','Puntuación por encima del promedio.' ,'Mejor puntuación.']
plt.figure(figsize=(10,6))  #tamaño de gráfico
plt.bar(lis,pregunta14.values,color='red')
plt.title('El proceso de enseñanza y mentoría en tu institución te facilita el crecimiento cognitivo, social y emocional.')
plt.xlabel('Opciones')#poner etiqueta a eje x
plt.ylabel('Puntuación')#poner etiqueta a eje y
plt.xticks(rotation=90)

## Mostrar las etiquetas en barras
for i, value in enumerate(pregunta14.values):
    plt.text(i, value, str(value), ha='center', va='bottom')

plt.show()#mostrar Gráfico

# %%
pregunta15=report[report['Questions']== 'The institute takes an active interest in promoting internships, student exchange, field visit opportunities for students.'][['Weightage 1','Weightage 2','Weightage 3','Weightage 4','Weightage 5']].sum()

# %%
pregunta15
# Out:
# Weightage 1     18
# Weightage 2     39
# Weightage 3    107
# Weightage 4     86
# Weightage 5    165
# dtype: int64

# %%
pregunta15=report[report['Questions']== 'The institute takes an active interest in promoting internships, student exchange, field visit opportunities for students.'][['Weightage 1','Weightage 2','Weightage 3','Weightage 4','Weightage 5']].sum()
dic = {'Weightage 1': 'Puntuación más baja en la escala.', 'Weightage 2': 'Puntuación por debajo del promedio pero mejor que la más baja.', 'Weightage 3':'Puntuación promedio.',
      'Weightage 4':'Puntuación por encima del promedio.' , 'Weightage 5': 'Mejor puntuación.'}
lis = ['Puntuación más baja en la escala.','Puntuación por debajo del promedio pero mejor que la más baja.','Puntuación promedio.','Puntuación por encima del promedio.' ,'Mejor puntuación.']
plt.figure(figsize=(10,6))  #tamaño de gráfico
plt.bar(lis,pregunta15.values,color='red')
plt.title('El instituto muestra un interés activo en promover prácticas, intercambios estudiantiles y oportunidades de visitas de campo para los estudiantes.')
plt.xlabel('Opciones')#poner etiqueta a eje x
plt.ylabel('Puntuación')#poner etiqueta a eje y
plt.xticks(rotation=90)

## Mostrar las etiquetas en barras
for i, value in enumerate(pregunta15.values):
    plt.text(i, value, str(value), ha='center', va='bottom')

plt.show()#mostrar Gráfico

# %%
pregunta16=report[report['Questions']== 'Was your performance in assignments discussed with you?'][['Weightage 1','Weightage 2','Weightage 3','Weightage 4','Weightage 5']].sum()

# %%
pregunta16
# Out:
# Weightage 1     13
# Weightage 2     39
# Weightage 3     68
# Weightage 4    123
# Weightage 5    172
# dtype: int64

# %%
pregunta16=report[report['Questions']== 'Was your performance in assignments discussed with you?'][['Weightage 1','Weightage 2','Weightage 3','Weightage 4','Weightage 5']].sum()
dic = {'Weightage 1': 'Puntuación más baja en la escala.', 'Weightage 2': 'Puntuación por debajo del promedio pero mejor que la más baja.', 'Weightage 3':'Puntuación promedio.',
      'Weightage 4':'Puntuación por encima del promedio.' , 'Weightage 5': 'Mejor puntuación.'}
lis = ['Puntuación más baja en la escala.','Puntuación por debajo del promedio pero mejor que la más baja.','Puntuación promedio.','Puntuación por encima del promedio.' ,'Mejor puntuación.']
plt.figure(figsize=(10,6))  #tamaño de gráfico
plt.bar(lis,pregunta16.values,color='red')
plt.title('¿Se discutió tu desempeño en las tareas contigo?')
plt.xlabel('Opciones')#poner etiqueta a eje x
plt.ylabel('Puntuación')#poner etiqueta a eje y
plt.xticks(rotation=90)

## Mostrar las etiquetas en barras
for i, value in enumerate(pregunta16.values):
    plt.text(i, value, str(value), ha='center', va='bottom')

plt.show()#mostrar Gráfico

# %%
pregunta17=report[report['Questions']== 'Fairness of the internal evaluation process by the teachers.'][['Weightage 1','Weightage 2','Weightage 3','Weightage 4','Weightage 5']].sum()

# %%
pregunta17
# Out:
# Weightage 1     10
# Weightage 2     25
# Weightage 3     51
# Weightage 4    140
# Weightage 5    189
# dtype: int64

# %%
pregunta17=report[report['Questions']== 'Fairness of the internal evaluation process by the teachers.'][['Weightage 1','Weightage 2','Weightage 3','Weightage 4','Weightage 5']].sum()
dic = {'Weightage 1': 'Puntuación más baja en la escala.', 'Weightage 2': 'Puntuación por debajo del promedio pero mejor que la más baja.', 'Weightage 3':'Puntuación promedio.',
      'Weightage 4':'Puntuación por encima del promedio.' , 'Weightage 5': 'Mejor puntuación.'}
lis = ['Puntuación más baja en la escala.','Puntuación por debajo del promedio pero mejor que la más baja.','Puntuación promedio.','Puntuación por encima del promedio.' ,'Mejor puntuación.']
plt.figure(figsize=(10,6))  #tamaño de gráfico
plt.bar(lis,pregunta17.values,color='red')
plt.title('Justicia del proceso de evaluación interna por parte de los profesores.')
plt.xlabel('Opciones')#poner etiqueta a eje x
plt.ylabel('Puntuación')#poner etiqueta a eje y
plt.xticks(rotation=90)

## Mostrar las etiquetas en barras
for i, value in enumerate(pregunta17.values):
    plt.text(i, value, str(value), ha='center', va='bottom')

plt.show()#mostrar Gráfico

# %%
pregunta18=report[report['Questions']== 'The teachers approach to teaching can best be described as'][['Weightage 1','Weightage 2','Weightage 3','Weightage 4','Weightage 5']].sum()

# %%
pregunta18
# Out:
# Weightage 1      7
# Weightage 2     36
# Weightage 3    108
# Weightage 4    151
# Weightage 5    113
# dtype: int64

# %%
pregunta18=report[report['Questions']== 'The teachers approach to teaching can best be described as?'][['Weightage 1','Weightage 2','Weightage 3','Weightage 4','Weightage 5']].sum()
dic = {'Weightage 1': 'Puntuación más baja en la escala.', 'Weightage 2': 'Puntuación por debajo del promedio pero mejor que la más baja.', 'Weightage 3':'Puntuación promedio.',
      'Weightage 4':'Puntuación por encima del promedio.' , 'Weightage 5': 'Mejor puntuación.'}
lis = ['Puntuación más baja en la escala.','Puntuación por debajo del promedio pero mejor que la más baja.','Puntuación promedio.','Puntuación por encima del promedio.' ,'Mejor puntuación.']
plt.figure(figsize=(10,6))  #tamaño de gráfico
plt.bar(lis,pregunta18.values,color='red')
plt.title('La mejor descripción del enfoque de enseñanza del profesor es')
plt.xlabel('Opciones')#poner etiqueta a eje x
plt.ylabel('Puntuación')#poner etiqueta a eje y
plt.xticks(rotation=90)

## Mostrar las etiquetas en barras
for i, value in enumerate(pregunta18.values):
    plt.text(i, value, str(value), ha='center', va='bottom')

plt.show()#mostrar Gráfico

# %%
pregunta19=report[report['Questions']== 'How well were the teachers able to communicate?'][['Weightage 1','Weightage 2','Weightage 3','Weightage 4','Weightage 5']].sum()

# %%
pregunta19
# Out:
# Weightage 1      7
# Weightage 2     24
# Weightage 3     54
# Weightage 4    134
# Weightage 5    196
# dtype: int64

# %%
pregunta19=report[report['Questions']== 'How well were the teachers able to communicate?'][['Weightage 1','Weightage 2','Weightage 3','Weightage 4','Weightage 5']].sum()
dic = {'Weightage 1': 'Puntuación más baja en la escala.', 'Weightage 2': 'Puntuación por debajo del promedio pero mejor que la más baja.', 'Weightage 3':'Puntuación promedio.',
      'Weightage 4':'Puntuación por encima del promedio.' , 'Weightage 5': 'Mejor puntuación.'}
lis = ['Puntuación más baja en la escala.','Puntuación por debajo del promedio pero mejor que la más baja.','Puntuación promedio.','Puntuación por encima del promedio.' ,'Mejor puntuación.']
plt.figure(figsize=(10,6))  #tamaño de gráfico
plt.bar(lis,pregunta19.values,color='red')
plt.title('¿Qué tan bien fueron capaces de comunicarse los profesores?')
plt.xlabel('Opciones')#poner etiqueta a eje x
plt.ylabel('Puntuación')#poner etiqueta a eje y
plt.xticks(rotation=90)

## Mostrar las etiquetas en barras
for i, value in enumerate(pregunta19.values):
    plt.text(i, value, str(value), ha='center', va='bottom')

plt.show()#mostrar Gráfico

# %%
pregunta20=report[report['Questions']== 'The overall quality of the teaching-learning process in your institute is very good.'][['Weightage 1','Weightage 2','Weightage 3','Weightage 4','Weightage 5']].sum()

# %%
pregunta20
# Out:
# Weightage 1      7
# Weightage 2     24
# Weightage 3     84
# Weightage 4    167
# Weightage 5    133
# dtype: int64

# %%
pregunta20=report[report['Questions']== 'The overall quality of the teaching-learning process in your institute is very good.'][['Weightage 1','Weightage 2','Weightage 3','Weightage 4','Weightage 5']].sum()
dic = {'Weightage 1': 'Puntuación más baja en la escala.', 'Weightage 2': 'Puntuación por debajo del promedio pero mejor que la más baja.', 'Weightage 3':'Puntuación promedio.',
      'Weightage 4':'Puntuación por encima del promedio.' , 'Weightage 5': 'Mejor puntuación.'}
lis = ['Puntuación más baja en la escala.','Puntuación por debajo del promedio pero mejor que la más baja.','Puntuación promedio.','Puntuación por encima del promedio.' ,'Mejor puntuación.']
plt.figure(figsize=(10,6))  #tamaño de gráfico
plt.bar(lis,pregunta20.values,color='red')
plt.title('La calidad general del proceso de enseñanza-aprendizaje en tu instituto es muy buena.')
plt.xlabel('Opciones')#poner etiqueta a eje x
plt.ylabel('Puntuación')#poner etiqueta a eje y
plt.xticks(rotation=90)

## Mostrar las etiquetas en barras
for i, value in enumerate(pregunta20.values):
    plt.text(i, value, str(value), ha='center', va='bottom')

plt.show()#mostrar Gráfico
